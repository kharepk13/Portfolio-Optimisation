# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_datareader import data,wb

# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1 = data.DataReader("HDFCBANK.NS", start = '2016-09-09' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
df2 = data.DataReader("BANKBARODA.NS", start = '2016-09-09' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
df3 = data.DataReader("BAJAJFINSV.NS", start = '2016-09-09' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
df4 = data.DataReader("ASIANPAINT.NS", start = '2016-09-09' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
df5 = data.DataReader("HINDUNILVR.NS", start = '2016-09-09' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
df6 = data.DataReader("INFY.NS", start = '2016-09-09' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
#df7 = data.DataReader("CRAFTSMAN.NS", start = '2021-03-30' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
df7 = data.DataReader("DRREDDY.NS", start = '2016-09-09' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
df8 = data.DataReader("ONGC.NS", start = '2016-09-09' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
df9 = data.DataReader("MOTHERSUMI.NS", start = '2016-09-09' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
#df10 = data.DataReader("ROSSARI.NS", start = '2020-08-01' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
df10 = data.DataReader("MARUTI.NS", start = '2016-09-09' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']
df11 = data.DataReader("TCS.NS", start = '2016-09-09' , end = '2019-01-01' , data_source = 'yahoo')['Adj Close']

# %%
df1.head()
# Out:
# Date
# 2016-09-09    628.812378
# 2016-09-12    623.695740
# 2016-09-14    618.603455
# 2016-09-15    623.549500
# 2016-09-16    632.442749
# Name: Adj Close, dtype: float64

# %%
frames = [df1, df2, df3 ,df4,df5,df6,df7,df8,df9,df10,df11]
data = pd.concat(frames,axis = 1,ignore_index = False)

# %%
data.head()
# Out:
#              Adj Close   Adj Close    Adj Close    Adj Close   Adj Close  \
# Date
# 2016-09-09  628.812378  170.714432  3028.815918  1134.662109  863.485107
# 2016-09-12  623.695740  160.587723  2937.484375  1118.054810  852.806885
# 2016-09-14  618.603455  167.090668  2898.057129  1126.769653  843.521606
# 2016-09-15  623.549500  165.402878  2960.691650  1136.405029  848.675049
# 2016-09-16  632.442749  163.566162  2889.722412  1118.587402  846.539368
#
#              Adj Close    Adj Close   Adj Close   Adj Close    Adj Close  \
# Date
# 2016-09-09  451.967712  3040.858887  136.193573  137.010452  5104.853516
# 2016-09-12  460.042389  2987.818115  134.083511  129.782974  5034.937500
# 2016-09-14  456.376038  3007.053955  132.587738  131.257538  5067.911133
# 2016-09-15  454.891998  2989.579834  132.748016  129.616821  5151.527832
# 2016-09-16  462.726715  2999.769043  133.709549  132.379044  5265.756348
#
#               Adj Close
# Date
# 2016-09-09  1067.314941
# ...

# %%
data.columns = ['HDFCBANK' ,'BOB', 'BAJAJFINSV','ASIAN_PAINT',
                'HINDUNILVR','INFY', 'DRREDDY', 'ONGC', 'MOTHERSONSUMI', 'MARUTI','TCS']

# %%
data.head()
# Out:
#               HDFCBANK         BOB   BAJAJFINSV  ASIAN_PAINT  HINDUNILVR  \
# Date
# 2016-09-09  628.812378  170.714432  3028.815918  1134.662109  863.485107
# 2016-09-12  623.695740  160.587723  2937.484375  1118.054810  852.806885
# 2016-09-14  618.603455  167.090668  2898.057129  1126.769653  843.521606
# 2016-09-15  623.549500  165.402878  2960.691650  1136.405029  848.675049
# 2016-09-16  632.442749  163.566162  2889.722412  1118.587402  846.539368
#
#                   INFY      DRREDDY        ONGC  MOTHERSONSUMI       MARUTI  \
# Date
# 2016-09-09  451.967712  3040.858887  136.193573     137.010452  5104.853516
# 2016-09-12  460.042389  2987.818115  134.083511     129.782974  5034.937500
# 2016-09-14  456.376038  3007.053955  132.587738     131.257538  5067.911133
# 2016-09-15  454.891998  2989.579834  132.748016     129.616821  5151.527832
# 2016-09-16  462.726715  2999.769043  133.709549     132.379044  5265.756348
#
#                     TCS
# Date
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 571 entries, 2016-09-09 to 2019-01-01
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HDFCBANK       571 non-null    float64
#  1   BOB            571 non-null    float64
#  2   BAJAJFINSV     571 non-null    float64
#  3   ASIAN_PAINT    571 non-null    float64
#  4   HINDUNILVR     571 non-null    float64
#  5   INFY           571 non-null    float64
#  6   DRREDDY        571 non-null    float64
#  7   ONGC           571 non-null    float64
#  8   MOTHERSONSUMI  571 non-null    float64
#  9   MARUTI         571 non-null    float64
#  10  TCS            571 non-null    float64
# dtypes: float64(11)
# memory usage: 53.5 KB

# %%
data.to_csv(r'E:\Project\Portfolio_before_covid.csv')

# %%
r = np.log(data/data.shift(1))

# %%
r.mean()*252*100
# Out:
# HDFCBANK         23.105357
# BOB             -14.384856
# BAJAJFINSV       33.859590
# ASIAN_PAINT       7.560846
# HINDUNILVR       30.861611
# INFY             13.653127
# DRREDDY          -7.832026
# ONGC             -2.931481
# MOTHERSONSUMI     5.949929
# MARUTI           15.582033
# TCS              22.899593
# dtype: float64

# %%
r.cov()*252*100
# Out:
#                HDFCBANK        BOB  BAJAJFINSV  ASIAN_PAINT  HINDUNILVR  \
# HDFCBANK       2.273642   0.364139    1.359276     0.801066    0.735425
# BOB            0.364139  19.080234    2.660684     1.543472    0.683285
# BAJAJFINSV     1.359276   2.660684    9.309332     2.521786    1.466699
# ASIAN_PAINT    0.801066   1.543472    2.521786     5.134811    1.376018
# HINDUNILVR     0.735425   0.683285    1.466699     1.376018    3.802811
# INFY           0.182944   0.503036    0.110250     0.425592    0.423588
# DRREDDY        0.265302   2.314097    1.419948     0.474517    0.045616
# ONGC           0.416714   2.351046    1.584730     0.715967    0.578081
# MOTHERSONSUMI  1.338158   4.190976    2.744791     1.564443    1.150996
# MARUTI         1.092312   2.354796    2.924782     1.972628    1.289681
# TCS            0.282302  -0.362395   -0.153795     0.058103    0.567391
#
#                    INFY   DRREDDY      ONGC  MOTHERSONSUMI    MARUTI       TCS
# ...

# %% [markdown]
# ALLOCATING RANDOM WEIGHTS TO THE STOCKS AND CHECKING VARIANCE OF RETURNS

# %%
weights = np.random.random(len(data.columns))

# %%
weights = weights/np.sum(weights)
weights
# Out:
# array([0.07322623, 0.08607455, 0.01352707, 0.08079143, 0.04843479,
#        0.00256221, 0.15224619, 0.15983566, 0.08353854, 0.17077499,
#        0.12898834])

# %%
#Expected return on Portfolio
np.sum(r.mean()*weights)*252*100
# Out:
# 7.503277870445385

# %%
#Expected Portfolio Varaiance
var = np.dot(weights.T,np.dot(r.cov()*252,weights))
var
# Out:
# 0.017125277627699192

# %%
#Expected Standard Deviation
np.sqrt(var)*100
# Out:
# 13.086358403963722

# %% [markdown]
# VARYING WEIGHT TO BUILD A EFFICIENT FRONTIER

# %%
preturn= []
pvariance = []
for p in range (5000):
    weights = np.random.random(len(data.columns))
    weights = weights/np.sum(weights)
    preturn.append(np.sum(r.mean()*weights)*252*100)    #Anuualized mean expected return
    pvariance.append(np.sqrt(np.dot(weights.T,np.dot(r.cov()*252,weights)))*100) #Expected Standard Deviation
    
preturn = np.array(preturn)
pvariance = np.array(pvariance)

# %%
plt.figure(figsize  =(15,5))
plt.scatter(pvariance,preturn,c=preturn/pvariance,marker='o')
plt.grid(True)
plt.xlabel('expected volatality')
plt.ylabel('expected return')
plt.colorbar(label='Sharpe Ratio')
plt.show()

# %% [markdown]
# # Function to return statistic:

# %%
def stats(weights):
    weights = np.array(weights)
    preturn = np.sum(r.mean()*weights)*252*100
    pvariance = np.sqrt(np.dot(weights.T,np.dot(r.cov()*252,weights)))*100
    return np.array([preturn,pvariance,preturn/pvariance])

# %% [markdown]
# # Finding efficient portfolio

# %%
import scipy.optimize as sco

# %%
# Function to maximize Sharpe Ratio 
def max_fun_sr(weights):
    return stats(weights)[2]
#Function to minimize Variance
def min_fun_var(weights):
    return stats(weights)[1]**2
def min_fun_std(weights):
    return stats(weights)[1]

# %%
#Constraints
eq_cons = {'type':'eq','fun':lambda x:np.sum(x)-1}

# %%
#weights bound btwn 0 and 1
noa = len(data.columns)
bnds =tuple((0,1) for x in range(noa))
wts = np.array([noa*[1./noa,]])

# %%
# Optimizing for getting minimum Variance for a portfolio
optv = sco.minimize(min_fun_var,wts,method = 'SLSQP',
                    options={'ftol': 1e-9, 'disp': False},
                    bounds =bnds , constraints = eq_cons)

# %%
optv['x'].round(3) #weights for minimum variance portfolio
# Out:
# array([0.327, 0.01 , 0.   , 0.071, 0.129, 0.102, 0.098, 0.1  , 0.   ,
#        0.036, 0.126])

# %%
# Opmizing for getting minimum standard deviation
opts = sco.minimize(min_fun_std,wts,method = 'SLSQP',
                    options={'ftol': 1e-9, 'disp': False},
                    bounds =bnds , constraints = eq_cons)

# %%
er = stats(optv['x'])[0]  #Minimum Variance Portfolio
ev = stats(optv ['x'])[1]
stats(optv['x'].round(3))
# Out:
# array([15.70780549, 10.29032271,  1.52646384])

# %%
srx = max(preturn)
[i for i,x in enumerate(preturn) if x == max(preturn)]
# Out:
# [4233]

# %%
sry = pvariance[4233]

# %%
trets = np.linspace(0.0,25.0,50)

# %%
tvols = []
for tret in trets:
    eq_cons_1 = {'type':'eq','fun':lambda x:stats(x)[0]-tret} #This 2 constraints ensure of getting Highest Sharpe Ratio
    eq_cons_2 = {'type':'eq','fun':lambda x:np.sum(x)-1}
    bnds =tuple((0,1) for x in range(noa))
    res = sco.minimize(min_fun_std,wts,method = 'SLSQP',
                       options={'ftol': 1e-9, 'disp': False},bounds =bnds ,
                       constraints = [eq_cons_1,eq_cons_2])
    tvols.append(res['fun'])
tvols = np.array(tvols)

# %%
sr =trets/tvols
srx = max(trets)
[i for i,x in enumerate(sr) if x == max(sr)]
# Out:
# [49]

# %%
sry = tvols[49]

# %% [markdown]
# # Efficient frontier (Minimum variance and maximum sharpe ratio)

# %%
plt.figure(figsize = (15,5))
plt.xlim(9,20.0)
plt.ylim(0.0,26.0)
plt.scatter(pvariance , preturn , c= preturn/pvariance , marker = 'o')
plt.scatter(tvols , trets , c = trets/tvols , marker = 'x')
plt.plot(ev , er,'v',color = 'red' , ms = 15)
plt.plot(trets[49] , tvols[49],'*',color = 'red' , ms = 15)

plt.grid(True)
plt.xlabel('expected volatality')
plt.ylabel('expected return')
plt.colorbar(label= 'Sharpe Ratio')
plt.show()

# %% [markdown]
# # CML

# %%
import scipy.interpolate as sci

# %%
# Selecting Portfolios on the efficient Frontier
ind = np.argmin(tvols)
evols = tvols[ind:]        #These array objects to be used for interpolation
erets = trets[ind:]

# %%
tck = sci.splrep(evols,erets) #Given the set of data points (x[i], y[i]) determine
                              #a smooth spline approximation of degree k on the interval

# %%
def f(x):
    return sci.splev(x,tck,der=0) #Given the knots and coefficients 
                                  #of a B-spline representation, evaluate the value 
                                  #of the smoothing polynomial and its derivatives.
def df(x):
    return sci.splev(x,tck,der=1)

# %%
# Mathematical conditions to be satisfied by Capital Market Line
def eqn(p,rf=0.04):
    eq1 = rf - p[0]
    eq2 = rf +p[1]*p[2]-f(p[2])
    eq3 = p[1]-df(p[2])
    return eq1, eq2, eq3

# %%
opt = sco.fsolve(eqn ,[6,25,8])
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
np.round(eqn(opt),3)
# Out:
# array([ 0.   ,  0.087, -1.071])

# %%
plt.figure(figsize = (15,5))
plt.xlim(5.0,20.0)
plt.ylim(0.0,26.0)
cx = np.linspace(0,25)
plt.scatter(pvariance , preturn , c= preturn/pvariance , marker = 'o')
plt.scatter(tvols , trets , c = trets/tvols , marker = 'x')
plt.plot(cx , opt[1]*cx + opt[0] , lw = 1.5)
plt.plot(ev , er,'v',color = 'red' , ms = 15)
plt.plot(opt[2] , f(opt[2]),'r*',color = 'red' , ms = 15)

plt.grid(True)
plt.xlabel('expected volatality')
plt.ylabel('expected return')
plt.colorbar(label= 'Sharpe Ratio')
plt.show()

# %%
res['x'].round(3)
# Out:
# array([0.412, 0.   , 0.075, 0.   , 0.266, 0.076, 0.006, 0.   , 0.   ,
#        0.005, 0.16 ])

# %%
plt.figure(figsize = (15,5))
plt.bar(np.array(data.columns) , res['x']*100)
plt.ylabel('Percentage of Portfolio Location')
plt.title('Portfolio Allocation')
plt.show()
